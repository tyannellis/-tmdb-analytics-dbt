# %%
import os
import pandas as pd
from dotenv import load_dotenv
import snowflake.connector
import streamlit as st
import streamlit as st
import pandas as pd
import plotly.express as px
load_dotenv()

# creating query statement
def run_query(query):
    conn = snowflake.connector.connect(
        user= os.getenv("user"),
    password=os.getenv("password"),
    account=os.getenv("account"),
    warehouse=os.getenv("warehouse"),
    database=os.getenv("database"),
    schema=os.getenv("schema_reporting")
    )
    cur = conn.cursor()
    cur.execute(query)
    df = cur.fetch_pandas_all()
    cur.close()
    conn.close()
    return df

# %%
# load dataframes
def load_table(table_name):
    return run_query(f"SELECT * FROM {table_name}")

creator_df= load_table('REPORTING_CREATOR_INSIGHTS')
genre_df = load_table('REPORTING_GENRE_INSIGHTS_SUMMARY')
tv_show_df = load_table('REPORTING__WEEKLY_TV_SHOW_PERFORMANCE')
networks_df = load_table('REPORTING_NETWORK_INSIGHTS_SUMMARY')
spoken_df = load_table('REPORTING_SPOKEN_LANGUAGES')

# %%
tv_show_df
# Out:
#    TRENDING_WEEK_START_DATE  TV_SHOW_ID  LIFETIME_VOTE_AVERAGE  \
# 0                2025-06-16       83867                  8.263
# 1                2025-06-16      215522                  7.000
# 2                2025-06-16      248830                  7.200
# 3                2025-06-16      245703                  7.900
# 4                2025-06-16      247718                  8.464
# 5                2025-06-16      241554                  7.300
# 6                2025-06-16        1668                  8.429
# 7                2025-06-16        1399                  8.457
# 8                2025-06-16      100088                  8.518
# 9                2025-06-16       60625                  8.688
# 10               2025-06-16      221300                  6.655
# 11               2025-06-16       37854                  8.700
# 12               2025-06-16       46195                  8.100
# 13               2025-06-16      285801                  6.500
# 14               2025-06-16      231280                  8.400
# 15               2025-06-16      232766                  8.018
# 16               2025-06-16      278331                  7.000
# 17               2025-06-16      203367                  7.875
# 18               2025-06-16      252320                  9.000
# 19               2025-06-16      288915                  6.200
#
#     LIFETIME_VOTE_COUNT                     SURROGATE_KEY  \
# 0                  1571  f13893073c146f69fa0ff3b57a4f6ee1
# 1                     1  920275978f040a2b2b8a0aef9871865c
# 2                    19  23e19549cd4f099ecd82afc5366fe863
# 3                   103  5eadb7d3fbae75eec1ed6e144a980c80
# 4                   208  774595cc449e362912202727613599c7
# 5                   122  36b2bddf0636d1c0fd1fbdb4dae3ab9f
# 6                  8406  8d1f4a2a16f8e726b515c644b1c09cc9
# 7                 25128  f57387381a07dc5cabb1ceff5124c40e
# 8                  6209  707cdbec68a743b1bbe11f4eee1fb46b
# 9                 10219  9d85d4045e00288e177cfaa3fbc95430
# 10                  435  b808d757320abb3d45c966468e7187b2
# 11                 4907  4ed92310580cba00c131fb7e637c3128
# 12                  483  6c4eec21323b9a4fbd8f7ba23e3db997
# 13                    5  bb5d64f636664b0120cae6c0726e925e
# 14                   29  d69805adbbb22d135ed541c73c644cb7
# 15                   57  a5dce7eaad3c2a5e57d7d3c114c42b5c
# 16                    1  0efb8e613e45bb6f6697e07223c6b5a8
# 17                    8  439573e9f84d5e0769dc285c343de68b
# 18                    5  ee75450acd222d9ca44a02cb31b629cc
# 19                   10  7c998b0eb0969f1a1f27711677d2eb82
#
#                          ORIGINAL_NAME                 LOCALIZED_NAME  \
# 0                                Andor                          Andor
# 1                        We Were Liars                  We Were Liars
# 2                                Stick                          Stick
# 3                              Dept. Q                        Dept. Q
# 4                              MobLand                        MobLand
# 5                            Murderbot                      Murderbot
# 6                              Friends                        Friends
# 7                      Game of Thrones                Game of Thrones
# 8                       The Last of Us                 The Last of Us
# 9                       Rick and Morty                 Rick and Morty
# 10                               FUBAR                          FUBAR
# 11                               ワンピース                      One Piece
# 12                                 化物語                     Monogatari
# 13  Ladrones: La tiara de santa Águeda               Suspicious Minds
# 14                                 굿보이                       GOOD BOY
# 15                                  광장                 Mercy for None
# 16                      남주의 첫날밤을 가져버렸다  The First Night with the Duke
# 17                               长安的荔枝                The Litchi Road
# 18                                 临江仙                           FEUD
# 19                              An!ela                         Aniela
#
#     NUMBER_OF_EPISODES  NUMBER_OF_SEASONS FIRST_EPISODE_AIR_DATE  \
# 0                   24                  2             2022-09-21
# 1                    8                  1             2025-06-18
# 2                   10                  1             2025-06-03
# 3                    9                  1             2025-05-29
# 4                   10                  1             2025-03-30
# 5                   10                  1             2025-05-15
# 6                  228                 10             1994-09-22
# 7                   73                  8             2011-04-17
# 8                   16                  2             2023-01-15
# 9                   81                  8             2013-12-02
# 10                  16                  2             2023-05-25
# 11                1135                 22             1999-10-20
# 12                  72                  5             2009-07-03
# 13                   6                  1             2025-06-13
# 14                  16                  1             2025-05-31
# 15                   8                  1             2025-06-06
# 16                  12                  1             2025-06-11
# 17                  35                  1             2025-06-07
# 18                  32                  1             2025-06-06
# 19                   8                  1             2025-06-11
#
#    ORIGINAL_LANGUAGE_CODE ORIGINAL_LANGUAGE_NAME    TV_SHOW_STATUS  \
# 0                      en                English             Ended
# 1                      en                English  Returning Series
# 2                      en                English  Returning Series
# 3                      en                English  Returning Series
# 4                      en                English  Returning Series
# 5                      en                English  Returning Series
# 6                      en                English             Ended
# 7                      en                English             Ended
# 8                      en                English  Returning Series
# 9                      en                English  Returning Series
# 10                     en                English  Returning Series
# 11                     ja               Japanese  Returning Series
# 12                     ja               Japanese  Returning Series
# 13                     es                Spanish  Returning Series
# 14                     ko                 Korean  Returning Series
# 15                     ko                 Korean             Ended
# 16                     ko                 Korean  Returning Series
# 17                     zh                Chinese  Returning Series
# 18                     zh                Chinese  Returning Series
# 19                     pl                 Polish  Returning Series
#
#    TV_SHOW_TYPE
# 0      Scripted
# 1      Scripted
# 2      Scripted
# 3      Scripted
# 4      Scripted
# 5      Scripted
# 6      Scripted
# 7      Scripted
# 8      Scripted
# 9      Scripted
# 10     Scripted
# 11     Scripted
# 12     Scripted
# 13   Miniseries
# 14     Scripted
# 15   Miniseries
# 16     Scripted
# 17     Scripted
# 18     Scripted
# 19     Scripted

# %%
# creating filters for week 
st.sidebar.title("Filters")
selected_week = st.sidebar.selectbox("Select Trending Week", tv_show_df['TRENDING_WEEK_START_DATE'].unique())
selected_language = st.sidebar.selectbox("Select Show language", tv_show_df['ORIGINAL_LANGUAGE_CODE'].unique())
selected_status = st.sidebar.selectbox('Select Show Status', tv_show_df['TV_SHOW_STATUS'].unique())
selected_type = st.sidebar.selectbox('Select Show Type', tv_show_df['TV_SHOW_TYPE'].unique())

filtered_df = tv_show_df[(tv_show_df['TRENDING_WEEK_START_DATE'] == selected_week)
& (tv_show_df['ORIGINAL_LANGUAGE_CODE'] == selected_language)
&  (tv_show_df['TV_SHOW_STATUS']== selected_language)
& (tv_show_df['TV_SHOW_STATUS'] == selected_type)]
# Out:
# 2025-06-20 09:29:55.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.871 Session state does not function when running a script without `streamlit run`
# 2025-06-20 09:29:55.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.975 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.978 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.985 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.991 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:55.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:56.001 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:56.004 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:56.007 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:56.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:29:56.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Header
st.title("📺 TMDB TV Show Trending Dashboard")

# KPIs
st.metric("Total Shows", len(filtered_df))
st.metric("Avg Vote", round(filtered_df['LIFETIME_VOTE_AVERAGE'].mean(), 2))
st.metric('Vote Count',filtered_df['LIFETIME_VOTE_COUNT'].sum())
# Out:
# 2025-06-20 09:30:00.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:00.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.011 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.017 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.020 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.028 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.038 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:01.041 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.header("🔥 Trending Shows")
fig_trending = px.bar(filtered_df.sort_values('LIFETIME_VOTE_COUNT', ascending=False).head(10),
                      x='LOCALIZED_NAME', y='LIFETIME_VOTE_COUNT',title='Top 10 Most Voted Shows')

# Update axis labels and layout
fig_trending.update_layout(
    xaxis_title='TV Show Name',
    yaxis_title='Lifetime Vote Count',
    title_x=0.5
)
st.plotly_chart(fig_trending)
# Out:
# 2025-06-20 09:30:05.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:05.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:05.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:05.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:05.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:05.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:05.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:05.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Creator Section
st.header("🎬 Top Creators")
fig_creators = px.bar(creator_df.sort_values('CREATOR_VOTING_AVERAGE', ascending=False).head(10),
                      x='CREATOR_NAME', y='CREATOR_VOTING_AVERAGE', title = 'Top 10 Creators')

# Update axis labels and layout
fig_trending.update_layout(
    xaxis_title='Creator Name',
    yaxis_title='Average Rating',
    title_x=0.5
)
st.plotly_chart(fig_trending)

# %%
# Language Section
st.header("🗣️ Language Distribution")
fig_lang = px.bar(spoken_df, x='LANGUAGE_NAME', y='NUMBER_OF_TV_SHOWS')
st.plotly_chart(fig_lang)
# Out:
# 2025-06-20 09:30:07.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:07.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:07.987 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:08.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:08.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:08.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:08.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:08.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Genre Section
st.header("🗣️ Language Distribution")
fig_lang = px.bar(genre_df, x='GENRE_NAME', y='GENRE_SHOW_COUNT')
st.plotly_chart(fig_lang)
# Out:
# 2025-06-20 09:30:09.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:09.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:09.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:09.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:09.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:09.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:09.682 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:09.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Networks
st.header("📡 Networks")
fig_networks = px.bar(networks_df.sort_values('NETWORK_VOTE_COUNT', ascending=False).head(10),
                      x='NETWORK_NAME', y='NETWORK_VOTE_COUNT')

# Update axis labels and layout
fig_trending.update_layout(
    xaxis_title='Network Name',
    yaxis_title='Vote Count',
    title_x=0.5
)
st.plotly_chart(fig_networks)
# Out:
# 2025-06-20 09:30:11.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:11.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:11.579 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:11.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:11.670 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:11.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:11.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-06-20 09:30:11.683 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
tv_show_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tv_show_df
#
# NameError: name 'tv_show_df' is not defined
